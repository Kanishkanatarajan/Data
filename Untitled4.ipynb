# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

iris = sns.load_dataset('iris')
print("First few rows of the Iris dataset:")
print(iris.head())
print("\nFeatures in the dataset:")
print(iris.columns)
print("\nDatatype of each feature:")
print(iris.dtypes)
print("\nFive-point summary of the features:")
print(iris.describe())
# Out:
# First few rows of the Iris dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Features in the dataset:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#
# Datatype of each feature:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
#
# Five-point summary of the features:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# ...

# %%
print("First few rows of the Iris dataset:")
print(iris.head())
# Out:
# First few rows of the Iris dataset:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print("\nFeatures in the dataset:")
print(iris.columns)
# Out:
# Features in the dataset:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
print("\nDatatype of each feature:")
print(iris.dtypes)
# Out:
# Datatype of each feature:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
print("\nFive-point summary of the features:")
print(iris.describe())
# Out:
# Five-point summary of the features:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print("\nMissing values in each feature:")
print(iris.isnull().sum())
# Out:
# Missing values in each feature:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print("\nUnique species in the dataset:")
print(iris['species'].value_counts())
# Out:
# Unique species in the dataset:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
iris.hist(figsize=(12, 8))
plt.show()

# %%
msno.matrix(iris)
plt.show()

# %%
sns.boxplot(data=iris)
plt.show()

# %%
sns.pairplot(iris)
plt.show()

# %%
# Grouping by species and calculating mean of each feature
print("\nMean of each feature grouped by species:")
print(iris.groupby('species').mean())
# Out:
# Mean of each feature grouped by species:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
# Violin plot to visualize the distribution of petal length by species
plt.figure(figsize=(10,6))
sns.violinplot(x='species', y='petal_length', data=iris)
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
c = np.corrcoef(iris['sepal_length'],iris['sepal_width'])
print('Correlations between sepal_length and sepal_width\n',c)
# Out:
# Correlations between sepal_length and sepal_width
#  [[ 1.         -0.11756978]
#  [-0.11756978  1.        ]]

# %%
plt.figure(figsize=(10,8), dpi =500)
sns.heatmap(c,annot=True,fmt=".2f", linewidth=.5)
plt.show()

# %%
# Pairwise KDE plot for petal length and width
sns.jointplot(x='petal_length', y='petal_width', data=iris, kind='kde', hue='species')
plt.show()
